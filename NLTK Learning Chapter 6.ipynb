# %% [markdown]
# # Chapter 6

# %%
import nltk

# %% [markdown]
# ### Gender Classification by Feature from Name

# %%
# Feature extraction function returns a dictionary of relevant features
def gender_features(word):
    return {'last_letter': word[-1]}  # feature set

gender_features('Jack')
# Out:
# {'last_letter': 'k'}

# %%
from nltk.corpus import names
import random
# list of tagged names
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Neo'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Trinity'))
# Out:
# 'female'

# %%
# evaluate performance
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.766

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     38.3 : 1.0
#              last_letter = 'k'              male : female =     31.9 : 1.0
#              last_letter = 'f'              male : female =     16.0 : 1.0
#              last_letter = 'p'              male : female =     11.9 : 1.0
#              last_letter = 'v'              male : female =     11.3 : 1.0
#              last_letter = 'm'              male : female =      9.4 : 1.0
#              last_letter = 'd'              male : female =      9.4 : 1.0
#              last_letter = 'o'              male : female =      8.4 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'g'              male : female =      5.3 : 1.0

# %%
# using first, last, number of each letters in a name, contains a letter
# this is called overfitting
def gender_features2(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count(%s)" % letter] = name.lower().count(letter)
        features["has(%s)" % letter] = (letter in name.lower())
    return features

# %%
gender_features2('John')
# Out:
# {'count(a)': 0,
#  'count(b)': 0,
#  'count(c)': 0,
#  'count(d)': 0,
#  'count(e)': 0,
#  'count(f)': 0,
#  'count(g)': 0,
#  'count(h)': 1,
#  'count(i)': 0,
#  'count(j)': 1,
#  'count(k)': 0,
#  'count(l)': 0,
#  'count(m)': 0,
#  'count(n)': 1,
#  'count(o)': 1,
#  'count(p)': 0,
#  'count(q)': 0,
#  'count(r)': 0,
#  'count(s)': 0,
#  'count(t)': 0,
#  'count(u)': 0,
#  'count(v)': 0,
#  'count(w)': 0,
#  'count(x)': 0,
#  'count(y)': 0,
#  'count(z)': 0,
#  'first_letter': 'j',
#  'has(a)': False,
#  'has(b)': False,
#  'has(c)': False,
#  'has(d)': False,
#  'has(e)': False,
#  'has(f)': False,
#  'has(g)': False,
#  'has(h)': True,
#  'has(i)': False,
#  'has(j)': True,
#  'has(k)': False,
#  'has(l)': False,
#  'has(m)': False,
#  'has(n)': True,
#  'has(o)': True,
#  'has(p)': False,
#  'has(q)': False,
#  'has(r)': False,
#  'has(s)': False,
#  'has(t)': False,
#  'has(u)': False,
#  'has(v)': False,
#  'has(w)': False,
#  'has(x)': False,
#  'has(y)': False,
#  'has(z)': False,
#  'last_letter': 'n'}

# %%
featuresets = [(gender_features2(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)  # overfitted classifier

# %%
# overfitted classifier
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.792

# %%
# split data into 3 sets, devtest is used for debugging and seeing the errors the classifier runs into
train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]

# %%
# create feature sets
train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
test_set = [(gender_features(n), gender) for (n, gender) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, devtest_set)
# Out:
# 0.777

# %%
# get errors from classifier
errors = []
for (name, tag) in devtest_names:
    guess = classifier.classify(gender_features(name))
    if guess != tag:
        errors.append((tag, guess, name))

# %%
for (tag, guess, name) in sorted(errors):
    print('correct=%-8s guess=%-8s name=%-30s' % (tag, guess, name))
# Out:
# correct=female   guess=male     name=Abigail
# correct=female   guess=male     name=Addis
# correct=female   guess=male     name=Adrian
# correct=female   guess=male     name=Allys
# correct=female   guess=male     name=Allyson
# correct=female   guess=male     name=Astrid
# correct=female   guess=male     name=Bab
# correct=female   guess=male     name=Babs
# correct=female   guess=male     name=Beau
# correct=female   guess=male     name=Beilul
# correct=female   guess=male     name=Bel
# correct=female   guess=male     name=Bliss
# correct=female   guess=male     name=Brier
# correct=female   guess=male     name=Brook
# correct=female   guess=male     name=Carol
# correct=female   guess=male     name=Caroleen
# correct=female   guess=male     name=Cat
# correct=female   guess=male     name=Catherin
# correct=female   guess=male     name=Cathyleen
# correct=female   guess=male     name=Cher
# correct=female   guess=male     name=Chriss
# correct=female   guess=male     name=Christen
# correct=female   guess=male     name=Ciel
# correct=female   guess=male     name=Cristen
# correct=female   guess=male     name=Cyb
# correct=female   guess=male     name=Danit
# correct=female   guess=male     name=Dawn
# correct=female   guess=male     name=Deb
# correct=female   guess=male     name=Dian
# correct=female   guess=male     name=Dido
# correct=female   guess=male     name=Doris
# correct=female   guess=male     name=Easter
# correct=female   guess=male     name=Elinor
# correct=female   guess=male     name=Elyn
# correct=female   guess=male     name=Eryn
# correct=female   guess=male     name=Ethelin
# correct=female   guess=male     name=Ethelind
# correct=female   guess=male     name=Fred
# correct=female   guess=male     name=Gabriell
# correct=female   guess=male     name=Gennifer
# correct=female   guess=male     name=Gertrudis
# correct=female   guess=male     name=Gilligan
# correct=female   guess=male     name=Gredel
# correct=female   guess=male     name=Grethel
# correct=female   guess=male     name=Grissel
# correct=female   guess=male     name=Gus
# correct=female   guess=male     name=Gwendolin
# correct=female   guess=male     name=Gwendolyn
# correct=female   guess=male     name=Gwenn
# correct=female   guess=male     name=Harriot
# correct=female   guess=male     name=Jacklyn
# correct=female   guess=male     name=Jackquelin
# correct=female   guess=male     name=Jacquelin
# correct=female   guess=male     name=Janet
# correct=female   guess=male     name=Jilleen
# correct=female   guess=male     name=Joan
# correct=female   guess=male     name=Joann
# correct=female   guess=male     name=Jocelin
# correct=female   guess=male     name=Joscelin
# correct=female   guess=male     name=Karalynn
# correct=female   guess=male     name=Karin
# correct=female   guess=male     name=Karleen
# correct=female   guess=male     name=Karlyn
# correct=female   guess=male     name=Katheryn
# correct=female   guess=male     name=Kristel
# correct=female   guess=male     name=Kym
# correct=female   guess=male     name=Lib
# correct=female   guess=male     name=Lynnett
# correct=female   guess=male     name=Mabel
# correct=female   guess=male     name=Madelyn
# correct=female   guess=male     name=Madlen
# correct=female   guess=male     name=Magdalen
# correct=female   guess=male     name=Maren
# correct=female   guess=male     name=Mariann
# correct=female   guess=male     name=Marigold
# correct=female   guess=male     name=Marys
# correct=female   guess=male     name=Mead
# correct=female   guess=male     name=Miran
# correct=female   guess=male     name=Muffin
# correct=female   guess=male     name=Muriel
# correct=female   guess=male     name=Nadeen
# correct=female   guess=male     name=Nert
# correct=female   guess=male     name=Nitin
# correct=female   guess=male     name=Noel
# correct=female   guess=male     name=Noelyn
# correct=female   guess=male     name=Pat
# correct=female   guess=male     name=Perl
# correct=female   guess=male     name=Phylys
# correct=female   guess=male     name=Quinn
# correct=female   guess=male     name=Regan
# correct=female   guess=male     name=Rosaleen
# correct=female   guess=male     name=Rosamond
# correct=female   guess=male     name=Roselin
# correct=female   guess=male     name=Shamit
# correct=female   guess=male     name=Sharyl
# correct=female   guess=male     name=Shirleen
# correct=female   guess=male     name=Sibyl
# correct=female   guess=male     name=Star
# correct=female   guess=male     name=Susan
# correct=female   guess=male     name=Suzann
# correct=female   guess=male     name=Sybyl
# correct=female   guess=male     name=Tamiko
# correct=female   guess=male     name=Taryn
# correct=female   guess=male     name=Tim
# correct=female   guess=male     name=Umeko
# correct=female   guess=male     name=Val
# correct=female   guess=male     name=Van
# correct=female   guess=male     name=Vin
# correct=female   guess=male     name=Wilow
# correct=female   guess=male     name=Winifred
# correct=male     guess=female   name=Adolphe
# correct=male     guess=female   name=Aldrich
# correct=male     guess=female   name=Alley
# correct=male     guess=female   name=Allie
# correct=male     guess=female   name=Ambrose
# correct=male     guess=female   name=Angie
# correct=male     guess=female   name=Anthony
# correct=male     guess=female   name=Antone
# correct=male     guess=female   name=Arvie
# correct=male     guess=female   name=Ashish
# correct=male     guess=female   name=Baily
# correct=male     guess=female   name=Barde
# correct=male     guess=female   name=Barri
# correct=male     guess=female   name=Bartolomei
# correct=male     guess=female   name=Bradly
# correct=male     guess=female   name=Brady
# correct=male     guess=female   name=Brody
# correct=male     guess=female   name=Burke
# correct=male     guess=female   name=Carey
# correct=male     guess=female   name=Chauncey
# correct=male     guess=female   name=Claire
# correct=male     guess=female   name=Clarence
# correct=male     guess=female   name=Connolly
# correct=male     guess=female   name=Dani
# correct=male     guess=female   name=Danny
# correct=male     guess=female   name=Dante
# correct=male     guess=female   name=Darcy
# correct=male     guess=female   name=Davey
# correct=male     guess=female   name=Dimitry
# correct=male     guess=female   name=Donny
# correct=male     guess=female   name=Earle
# correct=male     guess=female   name=Ely
# correct=male     guess=female   name=Emile
# correct=male     guess=female   name=Ferdie
# correct=male     guess=female   name=Fletch
# correct=male     guess=female   name=Freddy
# correct=male     guess=female   name=French
# correct=male     guess=female   name=Garth
# correct=male     guess=female   name=Geoffrey
# correct=male     guess=female   name=Gerri
# correct=male     guess=female   name=Grady
# correct=male     guess=female   name=Greggory
# correct=male     guess=female   name=Griffith
# correct=male     guess=female   name=Harvie
# correct=male     guess=female   name=Henri
# correct=male     guess=female   name=Hewie
# correct=male     guess=female   name=Ira
# correct=male     guess=female   name=Jae
# correct=male     guess=female   name=Jaime
# correct=male     guess=female   name=Jereme
# correct=male     guess=female   name=Jeremiah
# correct=male     guess=female   name=Jeremie
# correct=male     guess=female   name=Jerri
# correct=male     guess=female   name=Jerzy
# correct=male     guess=female   name=Jory
# correct=male     guess=female   name=Joseph
# correct=male     guess=female   name=Kalle
# correct=male     guess=female   name=Kingsley
# correct=male     guess=female   name=Kory
# correct=male     guess=female   name=Lance
# correct=male     guess=female   name=Lane
# correct=male     guess=female   name=Laurence
# correct=male     guess=female   name=Levi
# correct=male     guess=female   name=Levy
# correct=male     guess=female   name=Lex
# correct=male     guess=female   name=Lindsay
# correct=male     guess=female   name=Lorne
# correct=male     guess=female   name=Luke
# correct=male     guess=female   name=Mace
# correct=male     guess=female   name=Mahesh
# correct=male     guess=female   name=Marietta
# correct=male     guess=female   name=Martie
# correct=male     guess=female   name=Maurie
# correct=male     guess=female   name=Maury
# correct=male     guess=female   name=Mika
# correct=male     guess=female   name=Nate
# correct=male     guess=female   name=Neddy
# correct=male     guess=female   name=Nichole
# correct=male     guess=female   name=Noah
# correct=male     guess=female   name=Ossie
# correct=male     guess=female   name=Pennie
# correct=male     guess=female   name=Penny
# correct=male     guess=female   name=Quincey
# correct=male     guess=female   name=Rabi
# correct=male     guess=female   name=Randy
# correct=male     guess=female   name=Rich
# correct=male     guess=female   name=Richie
# correct=male     guess=female   name=Ricki
# correct=male     guess=female   name=Riley
# correct=male     guess=female   name=Rodolphe
# correct=male     guess=female   name=Roni
# correct=male     guess=female   name=Ronnie
# correct=male     guess=female   name=Sasha
# correct=male     guess=female   name=Shayne
# correct=male     guess=female   name=Shelby
# correct=male     guess=female   name=Sidney
# correct=male     guess=female   name=Stanley
# correct=male     guess=female   name=Tallie
# correct=male     guess=female   name=Tammy
# correct=male     guess=female   name=Terri
# correct=male     guess=female   name=Thorndike
# correct=male     guess=female   name=Timothy
# correct=male     guess=female   name=Torrance
# correct=male     guess=female   name=Torrey
# correct=male     guess=female   name=Trace
# correct=male     guess=female   name=Tracie
# correct=male     guess=female   name=Tracy
# correct=male     guess=female   name=Vasili
# correct=male     guess=female   name=Waverly
# correct=male     guess=female   name=Willy
# correct=male     guess=female   name=Wylie
# correct=male     guess=female   name=Yancy
# correct=male     guess=female   name=Zachariah

# %%
def gender_features(word):
    return {'suffix1': word[-1:],
            'suffix2': word[-2:]}

# %%
# suffix classifier
train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, devtest_set)
# Out:
# 0.786

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                  suffix2 = 'na'           female : male   =    146.6 : 1.0
#                  suffix2 = 'la'           female : male   =     65.1 : 1.0
#                  suffix1 = 'a'            female : male   =     39.8 : 1.0
#                  suffix1 = 'k'              male : female =     39.5 : 1.0
#                  suffix2 = 'ia'           female : male   =     33.8 : 1.0
#                  suffix2 = 'ld'             male : female =     32.5 : 1.0
#                  suffix2 = 'us'             male : female =     31.4 : 1.0
#                  suffix2 = 'ra'           female : male   =     31.1 : 1.0
#                  suffix2 = 'rt'             male : female =     30.1 : 1.0
#                  suffix2 = 'ta'           female : male   =     29.0 : 1.0

# %% [markdown]
# ## Document Classification

# %%
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

# %%
random.shuffle(documents)

# %%
# look at 2000 most common words (random)
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = [w for w, c in all_words.most_common()][:2000]

# %%
word_features
# Out:
# [',',
#  'the',
#  '.',
#  'a',
#  'and',
#  'of',
#  'to',
#  "'",
#  'is',
#  'in',
#  's',
#  '"',
#  'it',
#  'that',
#  '-',
#  ')',
#  '(',
#  'as',
#  'with',
#  'for',
#  'his',
#  'this',
#  'film',
#  'i',
#  'he',
#  'but',
#  'on',
#  'are',
#  't',
#  'by',
#  'be',
#  'one',
#  'movie',
#  'an',
#  'who',
#  'not',
#  'you',
#  'from',
#  'at',
#  'was',
#  'have',
#  'they',
#  'has',
#  'her',
#  'all',
#  '?',
#  'there',
#  'like',
#  'so',
#  'out',
#  'about',
#  'up',
#  'more',
#  'what',
#  'when',
#  'which',
#  'or',
#  'she',
#  'their',
#  ':',
#  'some',
#  'just',
#  'can',
#  'if',
#  'we',
#  'him',
#  'into',
#  'even',
#  'only',
#  'than',
#  'no',
#  'time',
#  'good',
#  'most',
#  'its',
#  'will',
#  'story',
#  'would',
#  'been',
#  'much',
#  'character',
#  'also',
#  'get',
#  'other',
#  'do',
#  'two',
#  'well',
#  'them',
#  'very',
#  'characters',
#  ';',
#  'first',
#  '--',
#  'after',
#  'see',
#  '!',
#  'way',
#  'because',
#  'make',
#  'life',
#  'off',
#  'too',
#  'any',
#  'does',
#  'really',
#  'had',
#  'while',
#  'films',
#  'how',
#  'plot',
#  'little',
#  'where',
#  'people',
#  'over',
#  'could',
#  'then',
#  'me',
#  'scene',
#  'man',
#  'bad',
#  'my',
#  'never',
#  'being',
#  'best',
#  'these',
#  'don',
#  'new',
#  'doesn',
#  'scenes',
#  'many',
#  'director',
#  'such',
#  'were',
#  'know',
#  'movies',
#  'through',
#  'here',
#  'action',
#  'great',
#  're',
#  'another',
#  'love',
#  'go',
#  'made',
#  'us',
#  'big',
#  'end',
#  'something',
#  'back',
#  '*',
#  'still',
#  'world',
#  'seems',
#  'work',
#  'those',
#  'makes',
#  'before',
#  'now',
#  'however',
#  'between',
#  'few',
#  '/',
#  'down',
#  'every',
#  'though',
#  'better',
#  'real',
#  'audience',
#  'enough',
#  'seen',
#  'take',
#  'around',
#  'both',
#  'going',
#  'performance',
#  'year',
#  'why',
#  'role',
#  'should',
#  'isn',
#  'old',
#  'same',
#  'gets',
#  'your',
#  'may',
#  'things',
#  'think',
#  'years',
#  'last',
#  'comedy',
#  'funny',
#  'actually',
#  've',
#  'long',
#  'look',
#  'almost',
#  'own',
#  'thing',
#  'fact',
#  'nothing',
#  'say',
#  'john',
#  'right',
#  'although',
#  'played',
#  'find',
#  'script',
#  'come',
#  'ever',
#  'cast',
#  'since',
#  'did',
#  'star',
#  'plays',
#  'young',
#  'show',
#  'comes',
#  'm',
#  'part',
#  'original',
#  'actors',
#  'screen',
#  'without',
#  'again',
#  'acting',
#  'three',
#  'day',
#  'each',
#  'point',
#  'lot',
#  'least',
#  'takes',
#  'guy',
#  'quite',
#  'himself',
#  'away',
#  'during',
#  'family',
#  'effects',
#  'course',
#  'goes',
#  'minutes',
#  'interesting',
#  'might',
#  'far',
#  'high',
#  'once',
#  'rather',
#  'must',
#  'anything',
#  'place',
#  'set',
#  'yet',
#  'watch',
#  'd',
#  'making',
#  'our',
#  'wife',
#  'hard',
#  'always',
#  'fun',
#  'didn',
#  'll',
#  'special',
#  'seem',
#  'bit',
#  'times',
#  'trying',
#  'hollywood',
#  'instead',
#  'give',
#  'want',
#  'picture',
#  'american',
#  'kind',
#  'job',
#  'sense',
#  'woman',
#  'home',
#  'having',
#  'series',
#  'actor',
#  'probably',
#  'help',
#  'half',
#  'along',
#  'men',
#  'everything',
#  'pretty',
#  'becomes',
#  'sure',
#  'black',
#  'together',
#  'dialogue',
#  'money',
#  'become',
#  'gives',
#  'given',
#  'looking',
#  'whole',
#  'watching',
#  'father',
#  '`',
#  'feel',
#  'everyone',
#  'music',
#  'wants',
#  'sex',
#  'less',
#  'done',
#  'horror',
#  'got',
#  'death',
#  'perhaps',
#  'city',
#  'next',
#  'especially',
#  'play',
#  'girl',
#  'mind',
#  '10',
#  'moments',
#  'looks',
#  'completely',
#  '2',
#  'mother',
#  'reason',
#  'whose',
#  'line',
#  'night',
#  'human',
#  'rest',
#  'performances',
#  'until',
#  'different',
#  'small',
#  'evil',
#  'james',
#  'simply',
#  'couple',
#  'put',
#  'let',
#  'anyone',
#  'ending',
#  'case',
#  'several',
#  'dead',
#  'michael',
#  'thought',
#  'left',
#  'school',
#  'humor',
#  'true',
#  'shows',
#  'friend',
#  'itself',
#  'lost',
#  'written',
#  'entire',
#  'getting',
#  'town',
#  'turns',
#  'soon',
#  'second',
#  'someone',
#  'stars',
#  'main',
#  'found',
#  'use',
#  'friends',
#  'problem',
#  'tv',
#  'top',
#  'begins',
#  'name',
#  'called',
#  'comic',
#  'based',
#  'david',
#  'head',
#  'else',
#  'idea',
#  'either',
#  'wrong',
#  'later',
#  'unfortunately',
#  'final',
#  'hand',
#  'alien',
#  'group',
#  'house',
#  'full',
#  'used',
#  'against',
#  'tries',
#  'often',
#  'war',
#  'sequence',
#  'keep',
#  'turn',
#  'behind',
#  'playing',
#  'named',
#  'boy',
#  'live',
#  'certainly',
#  'believe',
#  'under',
#  'relationship',
#  'works',
#  'face',
#  'hour',
#  'style',
#  'run',
#  'said',
#  'despite',
#  'person',
#  'finally',
#  'shot',
#  'book',
#  'doing',
#  'tell',
#  'maybe',
#  'nice',
#  'perfect',
#  'son',
#  'side',
#  'able',
#  'seeing',
#  'finds',
#  'children',
#  'days',
#  'past',
#  'summer',
#  'camera',
#  'won',
#  'including',
#  'mr',
#  'kids',
#  'lives',
#  'directed',
#  'moment',
#  'game',
#  'running',
#  'fight',
#  'supposed',
#  'video',
#  'matter',
#  'joe',
#  'kevin',
#  'car',
#  'lines',
#  '=',
#  'worth',
#  'daughter',
#  'earth',
#  'starts',
#  'need',
#  'entertaining',
#  'white',
#  'writer',
#  'start',
#  'dark',
#  'short',
#  'self',
#  'worst',
#  'nearly',
#  'try',
#  'opening',
#  'upon',
#  'care',
#  'early',
#  'violence',
#  'throughout',
#  'team',
#  'example',
#  'production',
#  'beautiful',
#  'jack',
#  'exactly',
#  'title',
#  'major',
#  'review',
#  'drama',
#  '&',
#  'sequences',
#  'problems',
#  'screenplay',
#  'version',
#  'obvious',
#  'known',
#  'killer',
#  'robert',
#  'wasn',
#  'disney',
#  'close',
#  'classic',
#  'already',
#  'others',
#  'kill',
#  'hit',
#  'deep',
#  'five',
#  'act',
#  'order',
#  'simple',
#  'fine',
#  'jackie',
#  'themselves',
#  'direction',
#  'heart',
#  'roles',
#  'eyes',
#  'four',
#  'question',
#  'sort',
#  'knows',
#  'sometimes',
#  'supporting',
#  'women',
#  'coming',
#  'voice',
#  'truly',
#  'save',
#  'jokes',
#  'computer',
#  'child',
#  'o',
#  'level',
#  '1',
#  'tom',
#  'boring',
#  'body',
#  'brother',
#  'strong',
#  'room',
#  'genre',
#  'stop',
#  'guys',
#  'space',
#  'ends',
#  'lee',
#  'beginning',
#  'ship',
#  'york',
#  'thriller',
#  'attempt',
#  'scream',
#  'peter',
#  'aren',
#  'husband',
#  'hero',
#  'happens',
#  'fiction',
#  'note',
#  'novel',
#  'hope',
#  'says',
#  'king',
#  'yes',
#  'tells',
#  'quickly',
#  'romantic',
#  'oscar',
#  'dog',
#  'possible',
#  'stupid',
#  'saw',
#  'lead',
#  'career',
#  'murder',
#  'extremely',
#  'god',
#  'manages',
#  'wonder',
#  'mostly',
#  'future',
#  'particularly',
#  'sound',
#  'fans',
#  'worse',
#  'de',
#  'involving',
#  'piece',
#  'involved',
#  'paul',
#  'appears',
#  'planet',
#  'laugh',
#  'hours',
#  'none',
#  'mean',
#  'taking',
#  'co',
#  'police',
#  'attention',
#  'sets',
#  'eventually',
#  'hell',
#  'fall',
#  'emotional',
#  'falls',
#  'material',
#  'single',
#  'power',
#  'late',
#  'dr',
#  'result',
#  'van',
#  'lack',
#  'meet',
#  'elements',
#  'smith',
#  'experience',
#  'wild',
#  'bring',
#  'science',
#  'theater',
#  'living',
#  'interest',
#  'leads',
#  'word',
#  'battle',
#  'feature',
#  'girls',
#  'alone',
#  'george',
#  'obviously',
#  'within',
#  'enjoy',
#  'usually',
#  'guess',
#  'among',
#  'aliens',
#  'feeling',
#  'laughs',
#  'taken',
#  'talk',
#  'talent',
#  'chance',
#  'easy',
#  'middle',
#  '3',
#  'number',
#  'across',
#  'attempts',
#  'needs',
#  'television',
#  'chris',
#  'happen',
#  'poor',
#  'deal',
#  'form',
#  'forced',
#  'viewer',
#  'girlfriend',
#  'release',
#  'killed',
#  'wonderful',
#  'whether',
#  'serious',
#  'tale',
#  'except',
#  'premise',
#  'oh',
#  'features',
#  'feels',
#  'light',
#  'expect',
#  'success',
#  'happy',
#  'history',
#  'words',
#  'important',
#  'leave',
#  'meets',
#  'type',
#  'giving',
#  'released',
#  'crew',
#  'art',
#  'parents',
#  'call',
#  'impressive',
#  'turned',
#  'working',
#  'mission',
#  'seemed',
#  'score',
#  'told',
#  'entertainment',
#  'basically',
#  'america',
#  'robin',
#  'recent',
#  '$',
#  'surprise',
#  'ryan',
#  'apparently',
#  'easily',
#  'cop',
#  'crime',
#  'stuff',
#  'change',
#  'office',
#  'cool',
#  'williams',
#  'somehow',
#  'sequel',
#  'parts',
#  'william',
#  'cut',
#  'die',
#  'jones',
#  'credits',
#  'batman',
#  'brings',
#  'suspense',
#  'events',
#  'reality',
#  'whom',
#  'local',
#  'difficult',
#  'talking',
#  'went',
#  'near',
#  'remember',
#  'hilarious',
#  'straight',
#  'writing',
#  'using',
#  'certain',
#  'ben',
#  'ago',
#  'wouldn',
#  'mystery',
#  'kid',
#  'slow',
#  'blood',
#  'popular',
#  'complete',
#  'red',
#  'am',
#  'fast',
#  'effective',
#  'due',
#  'flick',
#  'runs',
#  'gone',
#  'quality',
#  'presence',
#  'return',
#  'age',
#  'filmmakers',
#  'brothers',
#  'dramatic',
#  'general',
#  'business',
#  'rock',
#  'present',
#  'sexual',
#  'anyway',
#  'surprisingly',
#  'uses',
#  '4',
#  'personal',
#  'smart',
#  'figure',
#  'begin',
#  'couldn',
#  'ways',
#  'annoying',
#  'decides',
#  'somewhat',
#  'shots',
#  'rich',
#  'law',
#  'minute',
#  'motion',
#  'similar',
#  'absolutely',
#  'previous',
#  'successful',
#  'harry',
#  'water',
#  'jim',
#  'former',
#  'follow',
#  'project',
#  'million',
#  'read',
#  'strange',
#  'came',
#  'third',
#  'romance',
#  'secret',
#  'starring',
#  'excellent',
#  'intelligent',
#  'clear',
#  'amazing',
#  'familiar',
#  'budget',
#  'actress',
#  'party',
#  'means',
#  'prison',
#  'eye',
#  'company',
#  'latest',
#  'bob',
#  'powerful',
#  'nor',
#  'predictable',
#  'towards',
#  'beyond',
#  'visual',
#  'leaves',
#  'nature',
#  'following',
#  'r',
#  'villain',
#  'leaving',
#  'animated',
#  'wars',
#  'low',
#  'bill',
#  'b',
#  'filled',
#  'myself',
#  'sam',
#  'country',
#  'cinema',
#  'questions',
#  'box',
#  'message',
#  'herself',
#  'moving',
#  'martin',
#  'usual',
#  'create',
#  'clever',
#  'large',
#  'definitely',
#  'add',
#  'stories',
#  'situation',
#  'murphy',
#  'ones',
#  'brilliant',
#  'giant',
#  'felt',
#  'doubt',
#  'scary',
#  'opens',
#  'break',
#  'drug',
#  'bunch',
#  'thinking',
#  'solid',
#  'effect',
#  'move',
#  'learn',
#  'force',
#  'seriously',
#  'potential',
#  'saying',
#  'above',
#  'follows',
#  'huge',
#  'class',
#  'plan',
#  'agent',
#  'unlike',
#  'created',
#  'pay',
#  'sweet',
#  'non',
#  'perfectly',
#  'mark',
#  'married',
#  'audiences',
#  'ex',
#  'realize',
#  'decent',
#  'likely',
#  'subject',
#  'scott',
#  'dream',
#  'took',
#  'view',
#  'happened',
#  'enjoyable',
#  'understand',
#  'viewers',
#  'truman',
#  'studio',
#  'heard',
#  'open',
#  'immediately',
#  'e',
#  'cameron',
#  'points',
#  'bruce',
#  'frank',
#  'impossible',
#  'stay',
#  'cold',
#  'fails',
#  'richard',
#  'private',
#  'merely',
#  'exciting',
#  'overall',
#  'gun',
#  'mess',
#  'neither',
#  'wanted',
#  'ten',
#  'appear',
#  'free',
#  'carter',
#  'chase',
#  'fan',
#  'escape',
#  '+',
#  'ultimately',
#  'inside',
#  'haven',
#  'wedding',
#  'l',
#  'trek',
#  'modern',
#  'trouble',
#  'stone',
#  'favorite',
#  'brought',
#  'otherwise',
#  'allen',
#  '5',
#  'tim',
#  'bond',
#  'liked',
#  'dumb',
#  'society',
#  'talented',
#  'political',
#  'various',
#  'musical',
#  'stand',
#  'particular',
#  'west',
#  'state',
#  'keeps',
#  'situations',
#  'park',
#  'english',
#  'silly',
#  'u',
#  'steve',
#  'slightly',
#  'rating',
#  'truth',
#  'teen',
#  'air',
#  'joke',
#  'spend',
#  'key',
#  'element',
#  'eddie',
#  'members',
#  'government',
#  'focus',
#  'effort',
#  'biggest',
#  'hands',
#  'soundtrack',
#  'chan',
#  'earlier',
#  'purpose',
#  'today',
#  'showing',
#  'offers',
#  'max',
#  'memorable',
#  'cannot',
#  'six',
#  'mars',
#  'heavy',
#  'totally',
#  'rated',
#  'credit',
#  'control',
#  'fi',
#  'woody',
#  'wait',
#  'sci',
#  'ideas',
#  'sit',
#  'female',
#  ...]

# %%
# check (True|False) if the article contains a specific word from the list of 2000
def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({0})'.format(word)] = (word in document_words)
    return features

# %%
document_features(movie_reviews.words('pos/cv957_8737.txt'))
# Out:
# {'contains(thrive)': False,
#  'contains(sunny)': False,
#  'contains(available)': False,
#  'contains(accents)': False,
#  'contains(preening)': False,
#  'contains(multiples)': False,
#  'contains(jumps)': False,
#  'contains(procreation)': False,
#  'contains(crappy)': False,
#  'contains(homerian)': False,
#  'contains(pastoral)': False,
#  'contains(heretofore)': False,
#  'contains(overlays)': False,
#  'contains(eradicate)': False,
#  'contains(forecast)': False,
#  'contains(aggravating)': False,
#  'contains(entire)': False,
#  'contains(disheartened)': False,
#  'contains(idea)': True,
#  'contains(schillings)': False,
#  'contains(unrequited)': False,
#  'contains(shoddier)': False,
#  'contains(artwork)': False,
#  'contains(governed)': False,
#  'contains(depletion)': False,
#  'contains(afire)': False,
#  'contains(boiled)': False,
#  'contains(facinelli)': False,
#  'contains(humanity)': False,
#  'contains(assumption)': False,
#  'contains(unravel)': False,
#  'contains(littlest)': False,
#  'contains(cantonese)': False,
#  'contains(oooh)': False,
#  'contains(holographic)': False,
#  'contains(illinois)': False,
#  'contains(bullock)': False,
#  'contains(venality)': False,
#  'contains(martineau)': False,
#  'contains(horror)': False,
#  'contains(alessandro)': False,
#  'contains(weatherman)': False,
#  'contains(kien)': False,
#  'contains(pa)': False,
#  'contains(gossipy)': False,
#  'contains(nietzsche)': False,
#  'contains(botch)': False,
#  'contains(dawns)': False,
#  'contains(winger)': False,
#  'contains(brocade)': False,
#  'contains(manufacturing)': False,
#  'contains(ii_)': False,
#  'contains(pinching)': False,
#  'contains(trademarks)': False,
#  'contains(unite)': False,
#  'contains(preaches)': False,
#  'contains(hog)': False,
#  'contains(bartellemeo)': False,
#  'contains(bears)': False,
#  'contains(paces)': False,
#  'contains(coordinator)': False,
#  'contains(behavious)': False,
#  'contains(killer)': False,
#  'contains(virtues)': False,
#  'contains(drilling)': False,
#  'contains(staunton)': False,
#  'contains(amber)': False,
#  'contains(mia)': False,
#  'contains(cb)': False,
#  'contains(continuing)': False,
#  'contains(uncomplicated)': False,
#  'contains(naomi)': False,
#  'contains(slyly)': False,
#  'contains(folles)': False,
#  'contains(style)': False,
#  'contains(126)': False,
#  'contains(40)': False,
#  'contains(monty)': False,
#  'contains(riegert)': False,
#  'contains(prosperity)': False,
#  'contains(bartkowiak)': False,
#  'contains(decorum)': False,
#  'contains(recylcled)': False,
#  'contains(purveyor)': False,
#  'contains(mireniamu)': False,
#  'contains(coladas)': False,
#  'contains(paralyzingly)': False,
#  'contains(furnished)': False,
#  'contains(pharmacological)': False,
#  'contains(struggles)': False,
#  'contains(repetitiveness)': False,
#  'contains(simpithize)': False,
#  'contains(sheriff)': False,
#  'contains(mood)': False,
#  'contains(stoically)': False,
#  'contains(fell)': False,
#  'contains(energetically)': False,
#  'contains(readied)': False,
#  'contains(laverne)': False,
#  'contains(retail)': False,
#  'contains(shalit)': False,
#  'contains(baz)': False,
#  'contains(lone)': False,
#  'contains(gaunt)': False,
#  'contains(watchdog)': False,
#  'contains(disapproval)': False,
#  'contains(perplexed)': False,
#  'contains(tastelessness)': False,
#  'contains(frappacino)': False,
#  'contains(cleaning)': False,
#  'contains(pic)': False,
#  'contains(cityscapes)': False,
#  'contains(outrageously)': False,
#  'contains(trade)': False,
#  'contains(hayseed)': False,
#  'contains(nameless)': False,
#  'contains(boone)': False,
#  'contains(strain)': False,
#  'contains(nationwide)': False,
#  'contains(woodwinds)': False,
#  'contains(tex)': False,
#  'contains(illustrious)': False,
#  'contains(valmont)': False,
#  'contains(stargate)': False,
#  'contains(triggered)': False,
#  'contains(lines)': False,
#  'contains(chopper)': False,
#  'contains(olivia)': False,
#  'contains(prunella)': False,
#  'contains(sacred)': False,
#  'contains(mckellan)': False,
#  'contains(cynics)': False,
#  'contains(stansfield)': False,
#  'contains(signficance)': False,
#  'contains(dilemma)': False,
#  'contains(gouda)': False,
#  'contains(menken)': False,
#  'contains(brauvara)': False,
#  'contains(suicidal)': False,
#  'contains(victims)': False,
#  'contains(murrieta)': False,
#  'contains(bonfire)': False,
#  'contains(fantine)': False,
#  'contains(engagements)': False,
#  'contains(greenblatt)': False,
#  'contains(filmmaking)': False,
#  'contains(singin)': False,
#  'contains(energetic)': False,
#  'contains(woefully)': False,
#  'contains(forbidden)': False,
#  'contains(otherworldly)': False,
#  'contains(futures)': False,
#  'contains(steig)': False,
#  'contains(aryan)': False,
#  'contains(humoring)': False,
#  'contains(dummies)': False,
#  'contains(vamires)': False,
#  'contains(chaotic)': False,
#  'contains(mounting)': False,
#  'contains(warbling)': False,
#  'contains(disposed)': False,
#  'contains(jr)': False,
#  'contains(abba)': False,
#  'contains(bygone)': False,
#  'contains(moniker)': False,
#  'contains(organisations)': False,
#  'contains(betrays)': False,
#  'contains(damnit)': False,
#  'contains(crunching)': False,
#  'contains(fred)': False,
#  'contains(dysfuntion)': False,
#  'contains(nbsp)': False,
#  'contains(segues)': False,
#  'contains(carey)': False,
#  'contains(passe)': False,
#  'contains(subcontinent)': False,
#  'contains(fs)': False,
#  'contains(grapple)': False,
#  'contains(aboriginal)': False,
#  'contains(reemerging)': False,
#  'contains(gun)': True,
#  'contains(babies)': False,
#  'contains(sook)': False,
#  'contains(premium)': False,
#  'contains(1869)': False,
#  'contains(eschewed)': False,
#  'contains(reset)': False,
#  'contains(steve)': False,
#  'contains(globes)': False,
#  'contains(flushed)': False,
#  'contains(papers)': False,
#  'contains(arouses)': False,
#  'contains(freaking)': False,
#  'contains(larisa)': False,
#  'contains(deutch)': False,
#  'contains(psyched)': False,
#  'contains(hormones)': False,
#  'contains(endearment)': False,
#  'contains(involve)': False,
#  'contains(attila)': False,
#  'contains(lying)': False,
#  'contains(platonic)': False,
#  'contains(gellies)': False,
#  'contains(honchos)': False,
#  'contains(dotted)': False,
#  'contains(glides)': False,
#  'contains(mainly)': False,
#  'contains(crush)': False,
#  'contains(patriotism)': False,
#  'contains(mayhew)': False,
#  'contains(prima)': False,
#  'contains(rereleased)': False,
#  'contains(attending)': False,
#  'contains(_matewan_)': False,
#  'contains(pecked)': False,
#  'contains(bowman)': False,
#  'contains(onboard)': False,
#  'contains(resilient)': False,
#  'contains(1979)': False,
#  'contains(oversees)': False,
#  'contains(agent)': False,
#  'contains(pentameter)': False,
#  'contains(palace)': False,
#  'contains(kauffman)': False,
#  'contains(pledging)': False,
#  'contains(sparkler)': False,
#  'contains(odder)': False,
#  'contains(says)': False,
#  'contains(barnfield)': False,
#  'contains(korman)': False,
#  'contains(sobbing)': False,
#  'contains(niceness)': False,
#  'contains(dalliance)': False,
#  'contains(grips)': False,
#  'contains(averse)': False,
#  'contains(heiress)': False,
#  'contains(trini)': False,
#  'contains(darcy)': False,
#  'contains(average)': False,
#  'contains(playbook)': False,
#  'contains(barter)': False,
#  'contains(terminology)': False,
#  'contains(busses)': False,
#  'contains(credible)': False,
#  'contains(token)': False,
#  'contains(faint)': False,
#  'contains(mystify)': False,
#  'contains(subway)': False,
#  'contains(swampy)': False,
#  'contains(receipt)': False,
#  'contains(concealed)': False,
#  'contains(awake)': False,
#  'contains(gracie)': False,
#  'contains(ogden)': False,
#  'contains(heaving)': False,
#  'contains(eisenstein)': False,
#  'contains(schneider)': False,
#  'contains(input)': False,
#  'contains(dynasties)': False,
#  'contains(squirm)': False,
#  'contains(expirating)': False,
#  'contains(speaks)': False,
#  'contains(wrinkle)': False,
#  'contains(floors)': False,
#  'contains(enlightening)': False,
#  'contains(reusing)': False,
#  'contains(musn)': False,
#  'contains(357)': False,
#  'contains(preparation)': False,
#  'contains(humongous)': False,
#  'contains(outward)': False,
#  'contains(2hr)': False,
#  'contains(mothering)': False,
#  'contains(reeked)': False,
#  'contains(ted)': False,
#  'contains(followings)': False,
#  'contains(caberat)': False,
#  'contains(tiptoeing)': False,
#  'contains(infomercial)': False,
#  'contains(pays)': False,
#  'contains(radiates)': False,
#  'contains(earmarks)': False,
#  'contains(passenger)': False,
#  'contains(announced)': False,
#  'contains(celluloid)': False,
#  'contains(differentiated)': False,
#  'contains(roads)': False,
#  'contains(grouch)': False,
#  'contains(spawns)': False,
#  'contains(sordid)': False,
#  'contains(accounted)': False,
#  'contains(daze)': False,
#  'contains(international)': False,
#  'contains(grades)': False,
#  'contains(glowing)': False,
#  'contains(hehehe)': False,
#  'contains(communicating)': False,
#  'contains(microscopic)': False,
#  'contains(discharge)': False,
#  'contains(dryer)': False,
#  'contains(yapping)': False,
#  'contains(craftors)': False,
#  'contains(brownie)': False,
#  'contains(tieing)': False,
#  'contains(listed)': False,
#  'contains(pose)': False,
#  'contains(ventured)': False,
#  'contains(backtracks)': False,
#  'contains(quo)': False,
#  'contains(tarkovskian)': False,
#  'contains(orwell)': False,
#  'contains(thesis)': False,
#  'contains(skilfull)': False,
#  'contains(drunkenness)': False,
#  'contains(followed)': False,
#  'contains(infuriating)': False,
#  'contains(tend)': False,
#  'contains(alabama)': False,
#  'contains(plummer)': False,
#  'contains(protectively)': False,
#  'contains(recycling)': False,
#  'contains(pirates)': False,
#  'contains(peers)': False,
#  'contains(humiliating)': False,
#  'contains(freddy)': False,
#  'contains(brandis)': False,
#  'contains(aphrodiasiatic)': False,
#  'contains(condon)': False,
#  'contains(whipping)': False,
#  'contains(zealous)': False,
#  'contains(sublte)': False,
#  'contains(valley)': False,
#  'contains(floppy)': False,
#  'contains(liam)': False,
#  'contains(clinched)': False,
#  'contains(fernanda)': False,
#  'contains(waddle)': False,
#  'contains(nuisance)': False,
#  'contains(7000)': False,
#  'contains(purer)': False,
#  'contains(keynote)': False,
#  'contains(crusoe)': False,
#  'contains(bucket)': False,
#  'contains(geek)': False,
#  'contains(disloyal)': False,
#  'contains(glow)': False,
#  'contains(punctuating)': False,
#  'contains(psychoanalyst)': False,
#  'contains(adrianne)': False,
#  'contains(lanes)': False,
#  'contains(normally)': False,
#  'contains(jill)': False,
#  'contains(heather)': False,
#  'contains(renault)': False,
#  'contains(reaches)': False,
#  'contains(inhereit)': False,
#  'contains(begin)': False,
#  'contains(violator)': False,
#  'contains(punishing)': False,
#  'contains(vadis)': False,
#  'contains(initiated)': False,
#  'contains(fontenot)': False,
#  'contains(subdesarrollo)': False,
#  'contains(respectably)': False,
#  'contains(lyrics)': False,
#  'contains(depicted)': False,
#  'contains(glebas)': False,
#  'contains(anthropologists)': False,
#  'contains(tucci)': False,
#  'contains(tootsie)': False,
#  'contains(gigs)': False,
#  'contains(petite)': False,
#  'contains(luppi)': False,
#  'contains(sighs)': False,
#  'contains(coz)': False,
#  'contains(heroes)': False,
#  'contains(devised)': False,
#  'contains(isabel)': False,
#  'contains(permanently)': False,
#  'contains(emperors)': False,
#  'contains(zappa)': False,
#  'contains(sargeant)': False,
#  'contains(fisherman)': False,
#  'contains(vikings)': False,
#  'contains(rummaging)': False,
#  'contains(wrongdoings)': False,
#  'contains(disrespect)': False,
#  'contains(repellant)': False,
#  'contains(writed)': False,
#  'contains(protein)': False,
#  'contains(lanced)': False,
#  'contains(gracefully)': False,
#  'contains(chatterbox)': False,
#  'contains(striding)': False,
#  'contains(skies)': False,
#  'contains(sensitive)': False,
#  'contains(shortened)': False,
#  'contains(zakharov)': False,
#  'contains(equals)': False,
#  'contains(gorefests)': False,
#  'contains(labour)': False,
#  'contains(oneders)': False,
#  'contains(guile)': False,
#  'contains(talented)': False,
#  'contains(financiers)': False,
#  'contains(ellicit)': False,
#  'contains(foiling)': False,
#  'contains(carpets)': False,
#  'contains(questioning)': False,
#  'contains(dare)': False,
#  'contains(toughness)': False,
#  'contains(ingerman)': False,
#  'contains(doubtlessly)': False,
#  'contains(lime)': False,
#  'contains(it_)': False,
#  'contains(professing)': False,
#  'contains(commenting)': False,
#  'contains(enervation)': False,
#  'contains(nowadays)': False,
#  'contains(sorrow)': False,
#  'contains(implants)': False,
#  'contains(steptoe)': False,
#  'contains(dismayed)': False,
#  'contains(coogan)': False,
#  'contains(dialogueless)': False,
#  'contains(dillon)': False,
#  'contains(site)': False,
#  'contains(29)': False,
#  'contains(prepares)': False,
#  'contains(live)': False,
#  'contains(banalities)': False,
#  'contains(1957)': False,
#  'contains(overgrown)': False,
#  'contains(gregson)': False,
#  'contains(betters)': False,
#  'contains(chemicals)': False,
#  'contains(treehouse)': False,
#  'contains(expelling)': False,
#  'contains(plauged)': False,
#  'contains(emotionally)': False,
#  'contains(attired)': False,
#  'contains(fanatics)': False,
#  'contains(congregations)': False,
#  'contains(skirmish)': False,
#  'contains(noun)': False,
#  'contains(parading)': False,
#  'contains(cents)': False,
#  'contains(magazines)': False,
#  'contains(eno)': False,
#  'contains(joyful)': False,
#  'contains(_the_last_days_of_disco_)': False,
#  'contains(#@%$^)': False,
#  'contains(wonderbra)': False,
#  'contains(accepting)': False,
#  'contains(sleepless)': False,
#  'contains(mundy)': False,
#  'contains(dellaplane)': False,
#  'contains(terminus)': False,
#  'contains(fellatio)': False,
#  'contains(sandler)': False,
#  'contains(nyu)': False,
#  'contains(lavish)': False,
#  'contains(spewing)': False,
#  'contains(anglo)': False,
#  'contains(soviets)': False,
#  'contains(preservation)': False,
#  'contains(wrists)': False,
#  'contains(spectrum)': False,
#  'contains(complicate)': False,
#  'contains(dysfunctionality)': False,
#  'contains(privelege)': False,
#  'contains(rescued)': False,
#  'contains(ruse)': False,
#  'contains(couple)': False,
#  'contains(rockin)': False,
#  'contains(hobby)': False,
#  'contains(unispiring)': False,
#  'contains(determinedly)': False,
#  'contains(brassieres)': False,
#  'contains(sessions)': False,
#  'contains(/~)': False,
#  'contains(var)': False,
#  'contains(induce)': False,
#  'contains(wilma)': False,
#  'contains(rhodes)': False,
#  'contains(roldan)': False,
#  'contains(sobieski)': False,
#  'contains(unemployment)': False,
#  'contains(jon)': False,
#  'contains(unintelligble)': False,
#  'contains(owed)': False,
#  'contains(mexican)': False,
#  'contains(trundle)': False,
#  'contains(backbone)': False,
#  'contains(incompetency)': False,
#  'contains(mesh)': False,
#  'contains(scrupulous)': False,
#  'contains(kettle)': False,
#  'contains(sucked)': False,
#  'contains(credibility)': False,
#  'contains(hazing)': False,
#  'contains(unsexy)': False,
#  'contains(yagher)': False,
#  'contains(swelling)': False,
#  'contains(androgony)': False,
#  'contains(laxity)': False,
#  'contains(raunch)': False,
#  'contains(coca)': False,
#  'contains(johnny)': False,
#  'contains(telekinetically)': False,
#  'contains(marvels)': False,
#  'contains(alzheimer)': False,
#  'contains(nico)': False,
#  'contains(bedmates)': False,
#  'contains(flaunted)': False,
#  'contains(eisely)': False,
#  'contains(anticlimatic)': False,
#  'contains(preached)': False,
#  'contains(specter)': False,
#  'contains(cooney)': False,
#  'contains(croft)': False,
#  'contains(destroys)': False,
#  'contains(marley)': False,
#  'contains(biloxi)': False,
#  'contains(emphasized)': False,
#  'contains(tambor)': False,
#  'contains(attendees)': False,
#  'contains(insincerely)': False,
#  'contains(backfires)': False,
#  'contains(pimps)': False,
#  'contains(rapacious)': False,
#  'contains(mexicans)': False,
#  'contains(ciello)': False,
#  'contains(gabriel)': False,
#  'contains(reheal)': False,
#  'contains(evoking)': False,
#  'contains(pual)': False,
#  'contains(octogenarian)': False,
#  'contains(borderline)': False,
#  'contains(recants)': False,
#  'contains(amigos)': False,
#  'contains(highlights)': False,
#  'contains(twelfth)': False,
#  'contains(hortense)': False,
#  'contains(magma)': False,
#  'contains(uncommercial)': False,
#  'contains(overheated)': False,
#  'contains(beasts)': False,
#  'contains(lord)': False,
#  'contains(arctic)': False,
#  'contains(molina)': False,
#  'contains(bulbs)': False,
#  'contains(tapped)': True,
#  'contains(cropduster)': False,
#  'contains(lt)': False,
#  'contains(yeung)': False,
#  'contains(buckle)': False,
#  'contains(spazio)': False,
#  'contains(harvey)': False,
#  'contains(sandstorms)': False,
#  'contains(resulted)': False,
#  'contains(honour)': False,
#  'contains(edging)': False,
#  'contains(valli)': False,
#  'contains(preliminary)': False,
#  'contains(performence)': False,
#  'contains(motivations)': False,
#  'contains(stooges)': False,
#  'contains(foe)': False,
#  'contains(supplementing)': False,
#  'contains(burdened)': False,
#  'contains(close)': False,
#  'contains(false)': False,
#  'contains(slum)': False,
#  'contains(sections)': False,
#  'contains(celeste)': False,
#  'contains(pindar)': False,
#  'contains(frog)': False,
#  'contains(heldenberger)': False,
#  'contains(flops)': False,
#  'contains(menage)': False,
#  'contains(fairfax)': False,
#  'contains(kurring)': False,
#  'contains(buchenwald)': False,
#  'contains(illegally)': False,
#  'contains(deanna)': False,
#  'contains(stimulants)': False,
#  'contains(grungy)': False,
#  'contains(hiave)': False,
#  'contains(feng)': False,
#  'contains(worthier)': False,
#  'contains(pigeonholing)': False,
#  'contains(chompers)': False,
#  'contains(giddily)': False,
#  'contains(blandest)': False,
#  'contains(nightmare)': False,
#  'contains(danson)': False,
#  'contains(regulation)': False,
#  'contains(edgecomb)': False,
#  'contains(best)': True,
#  'contains(subverts)': False,
#  'contains(had)': False,
#  'contains(plane)': False,
#  'contains(droves)': False,
#  'contains(abberation)': False,
#  'contains(aviators)': False,
#  'contains(pairings)': False,
#  'contains(unlike)': False,
#  'contains(strength)': False,
#  'contains(offscreen)': False,
#  'contains(ajay)': False,
#  'contains(doli)': False,
#  'contains(prescient)': False,
#  'contains(alida)': False,
#  'contains(donald)': False,
#  'contains(comparatively)': False,
#  'contains(splish)': False,
#  'contains(adversity)': False,
#  'contains(modulation)': False,
#  'contains(_too_)': False,
#  'contains(polished)': False,
#  'contains(copes)': False,
#  'contains(yellowish)': False,
#  'contains(vampirism)': False,
#  'contains(brandishing)': False,
#  'contains(snubbed)': False,
#  'contains(mckellen)': False,
#  'contains(mildly)': False,
#  'contains(jackie)': True,
#  'contains(stalwart)': False,
#  'contains(uppance)': False,
#  'contains(invoke)': False,
#  'contains(responses)': False,
#  'contains(il)': False,
#  'contains(thunderclaps)': False,
#  'contains(wittier)': False,
#  'contains(vienna)': False,
#  'contains(happiness)': False,
#  'contains(furiously)': False,
#  'contains(sandwiched)': False,
#  'contains(democracy)': False,
#  'contains(collars)': False,
#  'contains(sidekick)': False,
#  'contains(pooches)': False,
#  'contains(downsides)': False,
#  'contains(resulting)': False,
#  'contains(developer)': False,
#  'contains(hazardus)': False,
#  'contains(ripened)': False,
#  'contains(aesthetic)': False,
#  'contains(beaker)': False,
#  'contains(finch)': False,
#  'contains(exorcism)': False,
#  'contains(crossover)': False,
#  'contains(embrassment)': False,
#  'contains(tabbed)': False,
#  'contains(reacting)': False,
#  'contains(whereas)': False,
#  'contains(treatments)': False,
#  'contains(reinvents)': False,
#  'contains(wildly)': False,
#  'contains(gap)': False,
#  'contains(hawaii)': False,
#  'contains(polite)': False,
#  'contains(commemorate)': False,
#  'contains(concentration)': False,
#  'contains(survivor)': False,
#  'contains(rickety)': False,
#  'contains(bicker)': False,
#  'contains(longer)': False,
#  'contains(flashes)': False,
#  'contains(ardour)': False,
#  'contains(neil)': False,
#  'contains(lesbos)': False,
#  'contains(trades)': False,
#  'contains(huckster)': False,
#  'contains(letterboxed)': False,
#  'contains(incapable)': False,
#  'contains(amphetimenes)': False,
#  'contains(eaten)': False,
#  'contains(exalted)': False,
#  'contains(dc)': False,
#  'contains(circulate)': False,
#  'contains(psychlo)': False,
#  'contains(lyonne)': False,
#  'contains(27)': False,
#  'contains(minimalist)': False,
#  'contains(reprimand)': False,
#  'contains(greenlight)': False,
#  'contains(fun)': True,
#  'contains(atmospheric)': False,
#  'contains(bolton)': False,
#  'contains(coquette)': False,
#  'contains(unsurpassed)': False,
#  'contains(sizzling)': False,
#  'contains(simplest)': False,
#  'contains(persuasively)': False,
#  'contains(greatly)': False,
#  'contains(demy)': False,
#  'contains(cio)': False,
#  'contains(screwball)': False,
#  'contains(palotti)': False,
#  'contains(funded)': False,
#  'contains(emphasizing)': False,
#  'contains(tickle)': False,
#  'contains(curtailed)': False,
#  'contains(lemay)': False,
#  'contains(prevents)': False,
#  'contains(sheltering)': False,
#  'contains(recidivist)': False,
#  'contains(mantegna)': False,
#  'contains(hayden)': False,
#  'contains(card)': False,
#  'contains(aaaaaah)': False,
#  'contains(exalts)': False,
#  'contains(oral)': False,
#  'contains(upper)': False,
#  'contains(damaging)': False,
#  'contains(budweiser)': False,
#  'contains(spurgin)': False,
#  'contains(directorial)': False,
#  'contains(cramp)': False,
#  'contains(bostwick)': False,
#  'contains(suceeds)': False,
#  'contains(guileless)': False,
#  'contains(hijacker)': False,
#  'contains(hotel)': False,
#  'contains(formula)': False,
#  'contains(forgotten)': False,
#  'contains(vip)': False,
#  'contains(flippers)': False,
#  'contains(reverting)': False,
#  'contains(herskovitz)': False,
#  'contains(oseransky)': False,
#  'contains(frewer)': False,
#  'contains(forte)': False,
#  'contains(courtland)': False,
#  'contains(glitzy)': False,
#  'contains(vampiric)': False,
#  'contains(cad)': False,
#  'contains(wilfrid)': False,
#  'contains(biological)': False,
#  'contains(progressive)': False,
#  'contains(automatically)': False,
#  'contains(windsor)': False,
#  'contains(mailheart)': False,
#  'contains(conspiratorial)': False,
#  'contains(hayes)': False,
#  'contains(lay)': False,
#  'contains(base)': False,
#  'contains(grinning)': False,
#  'contains(chi)': False,
#  'contains(views)': False,
#  'contains(contract)': False,
#  'contains(vortex)': False,
#  'contains(teleplay)': False,
#  'contains(wouldn)': False,
#  'contains(jail)': True,
#  'contains(thomspon)': False,
#  'contains(rascal)': False,
#  'contains(together)': False,
#  'contains(unsurprised)': False,
#  'contains(coma)': False,
#  'contains(rispoli)': False,
#  'contains(ticky)': False,
#  'contains(body)': False,
#  'contains(flashy)': False,
#  'contains(incoherent)': False,
#  'contains(weakling)': False,
#  'contains(twister)': False,
#  'contains(german)': False,
#  'contains(headstrong)': False,
#  'contains(despondent)': False,
#  'contains(undresses)': False,
#  'contains(returned)': False,
#  'contains(infomercials)': False,
#  'contains(kegger)': False,
#  'contains(precedents)': False,
#  'contains(dairy)': False,
#  'contains(1994)': False,
#  'contains(memo)': False,
#  'contains(reclusive)': False,
#  'contains(patterns)': False,
#  'contains(harriet)': False,
#  'contains(migraine)': False,
#  'contains(villainy)': False,
#  'contains(instantly)': False,
#  'contains(turns)': False,
#  'contains(quarrels)': False,
#  'contains(flour)': False,
#  'contains(tended)': False,
#  'contains(uuuhmm)': False,
#  'contains(punxsutawney)': False,
#  'contains(foresight)': False,
#  'contains(duets)': False,
#  'contains(businesses)': False,
#  'contains(symbolizes)': False,
#  'contains(products)': False,
#  'contains(launch)': False,
#  'contains(easter)': False,
#  'contains(grogan)': False,
#  'contains(insert)': False,
#  'contains(upstages)': False,
#  'contains(runneth)': False,
#  'contains(joker)': False,
#  'contains(arditi)': False,
#  'contains(estuff)': False,
#  'contains(rarest)': False,
#  'contains(unexceptional)': False,
#  'contains(trapping)': False,
#  'contains(entombed)': False,
#  'contains(pakula)': False,
#  'contains(kasdan)': False,
#  'contains(adhesive)': False,
#  'contains(faintly)': False,
#  'contains(deathcamps)': False,
#  'contains(enhance)': False,
#  'contains(psychopaths)': False,
#  'contains(spokesman)': False,
#  'contains(romantic)': False,
#  'contains(niceties)': False,
#  'contains(clung)': False,
#  'contains(@)': False,
#  'contains(heartwarming)': False,
#  'contains(figurine)': False,
#  'contains(poltergeist)': False,
#  'contains(awe)': False,
#  'contains(perch)': False,
#  'contains(teaser)': False,
#  'contains(schticks)': False,
#  'contains(rusty)': False,
#  'contains(abound)': False,
#  'contains(coffers)': False,
#  'contains(contracting)': False,
#  'contains(dunwich)': False,
#  'contains(hydrogen)': False,
#  'contains(ply)': False,
#  'contains(soften)': False,
#  'contains(stammers)': False,
#  'contains(feasting)': False,
#  'contains(erica)': False,
#  'contains(propel)': False,
#  'contains(retained)': False,
#  'contains(prevention)': False,
#  'contains(hysterical)': False,
#  'contains(implies)': False,
#  'contains(lukewarm)': False,
#  'contains(surmises)': False,
#  'contains(licking)': False,
#  'contains(homes)': False,
#  'contains(vassili)': False,
#  'contains(paola)': False,
#  'contains(wowing)': False,
#  'contains(tends)': False,
#  'contains(fenced)': False,
#  'contains(disdainful)': False,
#  'contains(haunted)': False,
#  'contains(grills)': False,
#  'contains(lunchmeat)': False,
#  'contains(midsummer)': False,
#  'contains(clubbing)': False,
#  'contains(racially)': False,
#  'contains(preaching)': False,
#  'contains(vibrates)': False,
#  'contains(covers)': False,
#  'contains(1992)': False,
#  'contains(nob)': False,
#  'contains(findings)': False,
#  'contains(writer)': False,
#  'contains(trance)': False,
#  'contains(november)': False,
#  'contains(bah)': False,
#  'contains(pumping)': False,
#  'contains(agendas)': False,
#  'contains(overtakes)': False,
#  'contains(once)': True,
#  'contains(simmer)': False,
#  'contains(tables)': False,
#  'contains(ghoulishness)': False,
#  'contains(surehanded)': False,
#  'contains(surely)': False,
#  'contains(arch)': False,
#  'contains(bloodsoaked)': False,
#  'contains(victim)': False,
#  'contains(sparked)': False,
#  'contains(tigerland)': False,
#  'contains(valkenburgh)': False,
#  'contains(ogres)': False,
#  'contains(crookier)': False,
#  'contains(randian)': False,
#  'contains(sargent)': False,
#  'contains(nordoff)': False,
#  'contains(minimums)': False,
#  'contains(disgusted)': False,
#  'contains(barcelona)': False,
#  'contains(backstabbing)': False,
#  'contains(matthews)': False,
#  'contains(supposedly)': False,
#  'contains(buck)': False,
#  'contains(kewpie)': False,
#  'contains(mention)': False,
#  'contains(coddling)': False,
#  'contains(bond)': False,
#  'contains(parks)': False,
#  'contains(rantings)': False,
#  'contains(negates)': False,
#  'contains(uncovered)': False,
#  'contains(poopies)': False,
#  'contains(aches)': False,
#  'contains(gasp)': True,
#  'contains(vci)': False,
#  'contains(contributions)': False,
#  'contains(characteristically)': False,
#  'contains(blemish)': False,
#  'contains(olive)': False,
#  'contains(schow)': False,
#  'contains(jhvh)': False,
#  'contains(favors)': False,
#  'contains(might)': False,
#  'contains(godawful)': False,
#  'contains(earthly)': False,
#  'contains(jeff)': False,
#  'contains(concussion)': False,
#  'contains(gotti)': False,
#  'contains(binding)': False,
#  'contains(faber)': False,
#  'contains(strapping)': False,
#  'contains(hippos)': False,
#  'contains(evers)': False,
#  'contains(keitel)': False,
#  'contains(beiderman)': False,
#  'contains(cookies)': False,
#  'contains(pushing)': False,
#  'contains(poombah)': False,
#  'contains(injection)': False,
#  'contains(rewards)': False,
#  'contains(girlina)': False,
#  'contains(donohue)': False,
#  'contains(autobiography)': False,
#  'contains(meekness)': False,
#  'contains(knuckleheaded)': False,
#  'contains(lusty)': False,
#  'contains(accident)': False,
#  'contains(hisses)': False,
#  'contains(caine)': False,
#  'contains(intact)': False,
#  'contains(secures)': False,
#  'contains(level)': False,
#  'contains(elmore)': False,
#  'contains(dutch)': False,
#  'contains(constantly)': False,
#  'contains(litany)': False,
#  'contains(diana)': False,
#  'contains(sonnets)': False,
#  'contains(nothin)': False,
#  'contains(alienated)': False,
#  'contains(psychodramas)': False,
#  'contains(blaring)': False,
#  'contains(rosalba)': False,
#  'contains(strutting)': False,
#  'contains(nincompoop)': False,
#  'contains(jasper)': False,
#  'contains(linc)': False,
#  'contains(such)': False,
#  'contains(admiting)': False,
#  'contains(hypnosis)': False,
#  'contains(faucet)': False,
#  'contains(dusty)': False,
#  'contains(slashing)': False,
#  'contains(portion)': False,
#  'contains(posesses)': False,
#  'contains(seana)': False,
#  'contains(coifed)': False,
#  'contains(lrighty)': False,
#  'contains(internetters)': False,
#  'contains(statue)': False,
#  'contains(assedly)': False,
#  'contains(blues)': False,
#  'contains(singed)': False,
#  'contains(grumpier)': False,
#  'contains(wb)': False,
#  'contains(wanton)': False,
#  'contains(recoiling)': False,
#  'contains(lucas)': False,
#  'contains(motion)': False,
#  'contains(winsomeness)': False,
#  'contains(mario)': False,
#  'contains(challenger)': False,
#  'contains(stranglehold)': False,
#  'contains(functionary)': False,
#  'contains(tails)': False,
#  'contains(lays)': False,
#  'contains(worldly)': False,
#  'contains(hangar)': False,
#  'contains(reign)': False,
#  'contains(atrocities)': False,
#  'contains(familiarize)': False,
#  'contains(happy)': False,
#  'contains(burley)': False,
#  'contains(song)': False,
#  ...}

# %%
# create the feature sets with labels
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.83

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#    contains(outstanding) = True              pos : neg    =     10.9 : 1.0
#         contains(seagal) = True              neg : pos    =      8.3 : 1.0
#          contains(mulan) = True              pos : neg    =      7.6 : 1.0
#    contains(wonderfully) = True              pos : neg    =      6.4 : 1.0
#          contains(damon) = True              pos : neg    =      6.1 : 1.0

# %% [markdown]
# ### Rule-Based POS Tagging with NB Classifier

# %%
from nltk.corpus import brown

suffix_fdist = nltk.FreqDist()
for word in brown.words():
    word = word.lower()
    suffix_fdist[word[-1:]] += 1
    suffix_fdist[word[-2:]] += 1
    suffix_fdist[word[-3:]] += 1

# %%
# get the most common suffixes (100), 1,2,3 letter suffixes
common_suffixes = [suffix for (suffix, count) in suffix_fdist.most_common(100)]

# %%
# get the feature counts
def pos_features(word):
    features = {}
    for suffix in common_suffixes:
        features['endswith(%s)' % suffix] = word.lower().endswith(suffix)
    return features

# %%
# create feature set for decision tree classifier
tagged_words = brown.tagged_words(categories='news')
featuresets = [(pos_features(n), g) for (n,g) in tagged_words]

# %%
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]

# %%
# create rule based classifier which uses common suffixes to guess on POS tag
classifier = nltk.DecisionTreeClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.6270512182993535

# %%
classifier.classify(pos_features('cats'))
# Out:
# 'NNS'

# %%
# print out the rules that choose the POS tag by suffix
print(classifier.pseudocode(depth=6))
# Out:
# if endswith(the) == False:
#   if endswith(,) == False:
#     if endswith(s) == False:
#       if endswith(.) == False:
#         if endswith(of) == False:
#           if endswith(and) == False: return '.'
#           if endswith(and) == True: return 'CC'
#         if endswith(of) == True: return 'IN'
#       if endswith(.) == True: return '.'
#     if endswith(s) == True:
#       if endswith(is) == False:
#         if endswith(was) == False:
#           if endswith(as) == False: return 'PP$'
#           if endswith(as) == True: return 'CS'
#         if endswith(was) == True: return 'BEDZ'
#       if endswith(is) == True:
#         if endswith(his) == False: return 'BEZ'
#         if endswith(his) == True: return 'PP$'
#   if endswith(,) == True: return ','
# if endswith(the) == True: return 'AT'

# %%
# Using More Context of a Sentence
def pos_features(sentence, i):
    features = {"suffix(1)": sentence[i][-1:],
                "suffix(2)": sentence[i][-2:],
                "suffix(3)": sentence[i][-3:]}
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    return features
pos_features(brown.sents()[0], 8)
# Out:
# {'prev-word': 'an', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion'}

# %%
tagged_sents = brown.tagged_sents(categories='news')

# %%
# build the feature sets
featuresets = []

for tagged_sent in tagged_sents:
    untagged_sent = nltk.tag.untag(tagged_sent)
    for i, (word, tag) in enumerate(tagged_sent):
        featuresets.append( (pos_features(untagged_sent, i), tag) )

# %%
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.7891596220785678

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                suffix(1) = '.'                 . : NN     =   6950.8 : 1.0
#                suffix(2) = 'he'               AT : NN     =   3296.2 : 1.0
#                suffix(2) = 'ho'              WPS : NN     =   2982.4 : 1.0
#                suffix(1) = 'r'               JJR : NNS    =   2252.6 : 1.0
#                suffix(2) = 'to'               TO : JJ     =   2180.6 : 1.0
#                suffix(1) = 'h'               ABX : NNS    =   2013.7 : 1.0
#                suffix(2) = 'es'              NNS : IN     =   1676.3 : 1.0
#                suffix(3) = 'hat'              CS : NN     =   1576.4 : 1.0
#                suffix(1) = "'"                '' : JJ     =   1502.2 : 1.0
#                suffix(2) = 'ng'              VBG : VBN    =   1241.0 : 1.0
