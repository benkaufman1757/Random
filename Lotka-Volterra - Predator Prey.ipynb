# %% [markdown]
# $\frac{dx}{dt} = ax-bxy$
#
# $\frac{dy}{dt} = dxy-cy$
#
# Where a is the growth rate of rabbits, b represents death rate of rabbits which depends on the number of foxes, c is the death rate of foxes, and d is how fast the foxes grow which depends on the number of rabbits.

# %%
from scipy import integrate
import numpy as np

from ipywidgets import interact
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models.widgets import Slider
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f9f7ec75-1668-4327-9a35-e247edea31af">Loading BokehJS ...</span>
#     </div>

# %%
a = 1.
b = 0.1
c = 1.5
d = 0.75

def dX_dt(X, t=0):
    """ Return the growth rate of fox and rabbit populations. """
    return np.array([ a*X[0] -   b*X[0]*X[1] ,
                  -c*X[1] + d*b*X[0]*X[1] ])

# %%
t = np.linspace(0, 50,  1000)              # time
X0 = np.array([10, 5])                     # initials conditions: 10 rabbits and 5 foxes
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
rabbits, foxes = X.T

f1 = figure(title="Evolution of fox and rabbit populations")
#plot1, = plt.plot(t, rabbits, 'r-', label='Rabbits')
#plot2, = plt.plot(t, foxes  , 'b-', label='Foxes')
#plt.grid()
#f1.legend(loc='best')
#f1.xlabel('time')
#f1.ylabel('population')
#f1.title('Evolution of fox and rabbit populations')
plot1 = f1.line(t,rabbits,color="red",legend="rabbits")
plot2 = f1.line(t,foxes,color="blue",legend="foxes")


def update(a,b,c,d):
    def inner_dX_dt(X, t=0):
        """ Return the growth rate of fox and rabbit populations. """
        return np.array([ a*X[0] -   b*X[0]*X[1] ,
                      -c*X[1] + d*b*X[0]*X[1] ])
    t = np.linspace(0, 50,  1000)              # time
    X0 = np.array([10, 5])                     # initials conditions: 10 rabbits and 5 foxes
    X, infodict = integrate.odeint(inner_dX_dt, X0, t, full_output=True)
    rabbits, foxes = X.T
    plot1.data_source.data['y'] = rabbits
    plot2.data_source.data['y'] = foxes
    push_notebook()

show(f1,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ffbef147-7d7c-4790-a6c5-910486b387bf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("ffbef147-7d7c-4790-a6c5-910486b387bf");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ffbef147-7d7c-4790-a6c5-910486b387bf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ffbef147-7d7c-4790-a6c5-910486b387bf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c1be447-78d7-4cff-9b50-7c7c9f681e29":{"roots":{"references":[{"attributes":{},"id":"092985ec-3008-4392-be5f-d864f1a64f2e","type":"SaveTool"},{"attributes":{},"id":"824882b8-24ae-466c-b2f4-26d09de162b8","type":"ResetTool"},{"attributes":{},"id":"68b58163-809e-4560-ae1d-22f03a784c68","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"94289c04-4e59-4e00-9465-7e1a969274db","type":"DataRange1d"},{"attributes":{},"id":"b65180ce-f176-4b22-93a0-b11efe84ac73","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"b9fbf0bf-567e-47e7-8aa8-56a55490ce64","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"37caf5ae-7777-40c5-8056-18986285ecb0","type":"LinearAxis"}],"left":[{"id":"52810bc7-f856-4f65-b789-9f460ca0642d","type":"LinearAxis"}],"renderers":[{"id":"37caf5ae-7777-40c5-8056-18986285ecb0","type":"LinearAxis"},{"id":"13d2679c-8c9c-45ba-954d-be2092194d91","type":"Grid"},{"id":"52810bc7-f856-4f65-b789-9f460ca0642d","type":"LinearAxis"},{"id":"cc753b22-cfa3-4365-a1cc-bd9af9713376","type":"Grid"},{"id":"d26d4f5d-1e31-44bd-8650-c2bbfcbc9252","type":"BoxAnnotation"},{"id":"9f61fb83-3948-4288-96e8-e1fc4e556a27","type":"Legend"},{"id":"d82cd191-c352-46c1-a2c6-2921744790d2","type":"GlyphRenderer"},{"id":"3c287a0a-21a1-4196-9709-17b5b0c8d005","type":"GlyphRenderer"}],"title":{"id":"cdf9a835-8e93-4903-a3bd-4c7edcc029bc","type":"Title"},"toolbar":{"id":"051e3e68-268c-4875-ab94-536d94033e74","type":"Toolbar"},"x_range":{"id":"94289c04-4e59-4e00-9465-7e1a969274db","type":"DataRange1d"},"x_scale":{"id":"16e5a2b7-212c-4ebf-ba79-1d6f6c808633","type":"LinearScale"},"y_range":{"id":"5a330285-bfa1-466e-a0e6-3d45e1824747","type":"DataRange1d"},"y_scale":{"id":"8774d41c-64b0-4ea2-ab6c-feb5f32d560b","type":"LinearScale"}},"id":"cb2aeb64-6daa-4257-9a2d-55165c5757f9","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"8522b5e2-4391-4dc3-9967-add035fb411c","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"72d094b1-8517-42d1-9589-a36cc58c0a98","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"291fc6d4-754b-43bd-860c-eb1b0271dc39","type":"PanTool"},{"id":"7c23c91c-1254-4275-84ac-c0fd035029a4","type":"WheelZoomTool"},{"id":"ba31b86d-e544-450c-8184-4af5811287ec","type":"BoxZoomTool"},{"id":"092985ec-3008-4392-be5f-d864f1a64f2e","type":"SaveTool"},{"id":"824882b8-24ae-466c-b2f4-26d09de162b8","type":"ResetTool"},{"id":"d61cd763-2d7d-4ddc-aebe-80f4e0e0badb","type":"HelpTool"}]},"id":"051e3e68-268c-4875-ab94-536d94033e74","type":"Toolbar"},{"attributes":{},"id":"d61cd763-2d7d-4ddc-aebe-80f4e0e0badb","type":"HelpTool"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c46b03a0-5f45-46f0-b049-e39e6bb3a12e","type":"Line"},{"attributes":{"plot":null,"text":"Evolution of fox and rabbit populations"},"id":"cdf9a835-8e93-4903-a3bd-4c7edcc029bc","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f88ef72-8aaa-42a6-bbc7-db99f752d8ee","type":"Line"},{"attributes":{},"id":"291fc6d4-754b-43bd-860c-eb1b0271dc39","type":"PanTool"},{"attributes":{"overlay":{"id":"d26d4f5d-1e31-44bd-8650-c2bbfcbc9252","type":"BoxAnnotation"}},"id":"ba31b86d-e544-450c-8184-4af5811287ec","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"07e72191-b93f-4433-90a7-1db797b9335d","type":"Line"},{"attributes":{},"id":"8774d41c-64b0-4ea2-ab6c-feb5f32d560b","type":"LinearScale"},{"attributes":{"formatter":{"id":"b65180ce-f176-4b22-93a0-b11efe84ac73","type":"BasicTickFormatter"},"plot":{"id":"cb2aeb64-6daa-4257-9a2d-55165c5757f9","subtype":"Figure ...

# %%
interact(update, a=(0,1,.01),b=(0,1,.01),c=(0,1,.01),d=(0,1,.01));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='a', max=1.0, step=0.01), FloatSlider(value=0.0, description='b', max=1.0, step=0.01), FloatSlider(value=0.0, description='c', max=1.0, step=0.01), FloatSlider(value=0.0, description='d', max=1.0, step=0.01), Output()), _dom_classes=('widget-interact',))
