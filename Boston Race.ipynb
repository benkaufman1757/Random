# %%
import pandas as pd
df = pd.read_csv('/Users/benkaufman/Desktop/boston_race.csv')
df = df.set_index('area')

# %%
df
# Out:
#                           total  white  black  american indian  asian  \
# area
# Allston                   29196  19319   1476               60   5585
# Back Bay                  18088  14893    750               15   1805
# Bay Village                1312    852     48                3    361
# Beacon Hill                9023   8116    187                6    486
# Brighton                  45801  34177   2349               73   6024
# Charlestown               16439  13164    949               35   1339
# Chinatown                  4444    779    139                2   3416
# Dorchester               114235  30267  52904              522  10679
# Downtown                  11215   8300   1002               20   1495
# East Boston               40508  26243   1812              211   1449
# Fenway                    33796  23523   1854               73   6277
# Harbor Islands              535    210    217                2      8
# ...

# %%
white_percentage = (df['white'] / df['total'])

# %%
white_percentage.sort(ascending=False,axis=1)

# %%
white_percentage
# Out:
# area
# North End                  0.935544
# Beacon Hill                0.899479
# South Boston Waterfront    0.892006
# Back Bay                   0.823364
# South Boston               0.806520
# Charlestown                0.800779
# Leather District           0.794992
# West Roxbury               0.771924
# West End                   0.751961
# Brighton                   0.746206
# Downtown                   0.740080
# Longwood Medical Area      0.739234
# Fenway                     0.696029
# Allston                    0.661700
# Bay Village                0.649390
# East Boston                0.647847
# Jamaica Plain              0.629097
# South End                  0.608862
# Roslindale                 0.569003
# Mission Hill               0.543637
# Harbor Islands             0.392523
# Hyde Park                  0.348337
# Dorchester                 0.264954
# Roxbury                    0.184794
# Chinatown                  0.175293
# Mattapan                   0.085885
# ...

# %%
black_percentage = (df['black'] / df['total'])
black_percentage.sort(ascending=False,axis=1)
black_percentage
# Out:
# area
# Mattapan                   0.798628
# Roxbury                    0.569922
# Hyde Park                  0.501550
# Dorchester                 0.463116
# Harbor Islands             0.405607
# Roslindale                 0.240307
# Mission Hill               0.180313
# Jamaica Plain              0.159870
# South End                  0.137852
# West Roxbury               0.106385
# Downtown                   0.089345
# South Boston               0.079944
# Longwood Medical Area      0.069485
# Charlestown                0.057729
# Fenway                     0.054859
# Brighton                   0.051287
# Allston                    0.050555
# East Boston                0.044732
# Back Bay                   0.041464
# West End                   0.039461
# Leather District           0.039124
# Bay Village                0.036585
# Chinatown                  0.031278
# Beacon Hill                0.020725
# South Boston Waterfront    0.019587
# North End                  0.012042
# ...

# %%
asian_percentage = (df['asian'] / df['total'])
asian_percentage.sort(ascending=False,axis=1)
asian_percentage
# Out:
# area
# Chinatown                  0.768677
# Bay Village                0.275152
# Allston                    0.191293
# Fenway                     0.185732
# West End                   0.167402
# South End                  0.162184
# Mission Hill               0.148727
# Longwood Medical Area      0.134742
# Downtown                   0.133304
# Leather District           0.133020
# Brighton                   0.131526
# Back Bay                   0.099790
# Dorchester                 0.093483
# Charlestown                0.081453
# West Roxbury               0.064836
# South Boston Waterfront    0.060879
# Beacon Hill                0.053862
# South Boston               0.046801
# Jamaica Plain              0.045052
# East Boston                0.035771
# North End                  0.028625
# Roslindale                 0.027615
# Roxbury                    0.027015
# Mattapan                   0.017301
# Hyde Park                  0.016451
# Harbor Islands             0.014953
# ...
