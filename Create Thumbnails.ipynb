# %%
from PIL import Image

# %%
x = Image.open('/Users/benkaufman/infographic/pos/10 Great Timeline Infographics | Infographic Design.jpg')

# %%
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1000 at 0x105D824D0>

# %%
x.thumbnail((120,120))

# %%
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=120x48 at 0x105D824D0>

# %%
import os

# %%
os.listdir('/Users/benkaufman/infographic/pos/')
# Out:
# ['10 free tools for creating infographics | Infographic | Creative Bloq.jpg',
#  '10 Great Timeline Infographics | Infographic Design.jpg',
#  '1388769567-let-go-keep-simple- ....jpg',
#  '1388769585-let-go-keep-simple- ....jpg',
#  '1397168889-formula-startups- ....jpg',
#  '1420832715-focus-info.jpg.jpg',
#  '15 Free Infographic Design Kits (PSD, AI, and EPS Files ....jpg',
#  '15 Years of Google Search - Blog About Infographics and Data ....jpg',
#  '17 Beautiful Examples Of Clean And Minimal Infographics | Designbeep.jpg',
#  '17 Cool Infographic Design Templates iDesignow, simple ....jpg',
#  '18 Smoothie Recipes - The Infographics.jpg',
#  '20 Interesting Infographics on Design.jpg',
#  '3 Trends That Will Define The Future Of Infographics CoDesign ....jpg',
#  '3 Trends That Will Define The Future Of Infographics | Co.Design ....jpg',
#  '30 Useful Infographics for Designers &amp; Developers ~ Creative ....jpg',
# ...

# %%
path ='/Users/benkaufman/infographic/neg/'
for img in os.listdir(path):
    if img != 'thumbs':
        print path+img
        temp = Image.open(path+img)
        temp2 = temp.resize((120,120))
        temp2.save(path+'thumbs/'+img)
# Out:
# /Users/benkaufman/infographic/neg/0086da0d44dc576311d06b1d121c1884e6aac686.jpg
# /Users/benkaufman/infographic/neg/00fe813a109961e2c19ffb045d28bbd693e60126.jpg
# /Users/benkaufman/infographic/neg/01e9b0488462c39ef19d010c654880f26395b18d.jpg
# /Users/benkaufman/infographic/neg/02650b02209458dfb49b89d3c0716b19e9240579.jpg
# /Users/benkaufman/infographic/neg/02c01fba0f8008498179f3b159b91d87e9ed41a2.jpg
# /Users/benkaufman/infographic/neg/032d4cb67a6565b358dbfd2df9f6174b2908aec8.jpg
# /Users/benkaufman/infographic/neg/04139a49147c940caa702b4fb6a81b3380726b5d.jpg
# /Users/benkaufman/infographic/neg/0430ca7907cd563f42268b077a115a15d60a9093.jpg
# /Users/benkaufman/infographic/neg/04840502d7b4bb67d3de9d95578ac74b969b9da7.jpg
# /Users/benkaufman/infographic/neg/053e99870642a99022c224d8ca040506ed24598d.jpg
# /Users/benkaufman/infographic/neg/057b8d0ad7d08141fe9b3cfa245c64c02c64857d.jpg
# /Users/benkaufman/infographic/neg/0600343e2fd7643c045b8c6428befb1b0136c797.jpg
# ...

# %%
os.path.exists('/Users/benkaufman/infographic/pos/10 free tools for creating infographics | Infographic | Creative Bloq.jpg')
# Out:
# True

# %%
x = Image.open('/Users/benkaufman/infographic/pos/10 free tools for creating infographics | Infographic | Creative Bloq.jpg').thumbnail((120,120))

# %%
x.thumbnail((128,128))

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=99x128 at 0x106A9DD50>

# %%
import numpy as np
import cv2

# %%
im = cv2.imread('/Users/benkaufman/infographic/pos/thumbs/10 free tools for creating infographics | Infographic | Creative Bloq.jpg',0)

# %%
im.shape
# Out:
# (120, 120)

# %%
im.shape
# Out:
# (120, 120)

# %%
temp.size
# Out:
# (120, 67)

# %%
path= '/Users/benkaufman/infographic/neg/thumbs/'
for x in os.listdir(path):
    t = Image.open(path+x)
    print t.size
# Out:
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# (120, 120)
# ...

# %%
120*120
# Out:
# 14400

# %%
im
# Out:
# array([[253, 252, 252, ..., 255, 242, 255],
#        [231, 222, 217, ..., 223, 207, 218],
#        [238, 221, 215, ..., 228, 209, 216],
#        ...,
#        [233, 211, 220, ..., 224, 218, 224],
#        [241, 213, 227, ..., 229, 212, 216],
#        [238, 205, 218, ..., 227, 212, 220]], dtype=uint8)

# %%
#images = []
pos_path = '/Users/benkaufman/infographic/pos/thumbs/'
neg_path = '/Users/benkaufman/infographic/neg/thumbs/'
for img in os.listdir(pos_path):
    temp = cv2.imread(pos_path+img,0)
    images.append((temp, 1))

# %%
images = np.array(images).reshape((len(images),-1))

# %%
120*120
# Out:
# 14400

# %%
target = np.repeat(1,len(images))

# %%
images2 = np.array(images2).reshape((len(images2),-1))

# %%
images2.shape
# Out:
# (297, 14400)

# %%
target2 = np.repeat(0,len(images2))

# %%
target += target2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-88675b9e1169> in <module>()
# ----> 1 target += target2
#
# ValueError: operands could not be broadcast together with shapes (154,) (297,) (154,)

# %%
images.shap
# Out:
# (451, 2)

# %%
images = np.array(images)

# %%
np.random.shuffle(images)

# %%
images[5]
# Out:
# array([ array([[200, 200, 200, ..., 200, 200, 200],
#        [200, 200, 200, ..., 200, 200, 200],
#        [200, 200, 200, ..., 200, 200, 200],
#        ...,
#        [255, 254, 207, ..., 225, 248, 253],
#        [246, 255, 244, ..., 225, 239, 255],
#        [255, 255, 250, ..., 251, 255, 253]], dtype=uint8),
#        1], dtype=object)

# %%
images.shape
# Out:
# (154, 2)

# %%
data, target = zip(*images)
data, target = np.array(list(data)), np.array(list(target))

# %%
pdata = data.reshape((len(data),-1))

# %%
pdata.shape
# Out:
# (451, 14400)

# %%
from sklearn import svm, metrics

# %%
clf = svm.SVC(gamma=0.001)

# %%
cuttoff = 400
clf.fit(pdata[:cuttoff], target[:cuttoff])
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.001, kernel='rbf', max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)

# %%
predicted, expected = clf.predict(pdata[cuttoff:]), target[400:]

# %%
print("Classification report for classifier %s:\n%s\n"
      % (clf, metrics.classification_report(expected, predicted)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
# Out:
# Classification report for classifier SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.001, kernel='rbf', max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#           0       0.61      1.00      0.76        31
#           1       0.00      0.00      0.00        20
#
# avg / total       0.37      0.61      0.46        51
#
#
# Confusion matrix:
# [[31  0]
#  [20  0]]
# /Library/Python/2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
