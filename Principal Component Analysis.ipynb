# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt

from scipy import linalg
from scipy import ndimage

# %%
A = [[2/5,-1],
     [11/5,2]]

# %%
U,S,V = np.linalg.svd(A)

# %%
Q,S = linalg.polar(A)

# %%
Q
# Out:
# array([[ 0.6, -0.8],
#        [ 0.8,  0.6]])

# %%
S
# Out:
# array([[ 2.,  1.],
#        [ 1.,  2.]])

# %%
Q,Sp = linalg.polar(A,side='left')

# %%
Sp
# Out:
# array([[ 2.,  1.],
#        [ 1.,  3.]])

# %%
faces = ndimage.imread("data/faces.jpg")
m, n = 112, 92
faces.shape
# Out:
# (2712, 2232)

# %%
faceholder = np.zeros((m,n))
for x in range(0,facem-m,m):
    for y in range(0,facen-n,n):
        lx = x + int(x/m)
        rx = x + m + int(x/m)
        ly = y + int(y/n)
        ry = y + n + int(y/n)
        Q,_ = linalg.polar(faces[lx:rx][:,ly:ry])
        faceholder += Q
faceholder/576
# Out:
# array([[ 0.02592308,  0.03057875,  0.04769842, ...,  0.04113038,
#          0.02493474,  0.02211819],
#        [ 0.02701813,  0.04943114,  0.03931888, ...,  0.0242802 ,
#          0.06184168,  0.03929142],
#        [ 0.03900641,  0.03654355,  0.02629908, ...,  0.046231  ,
#          0.02098014,  0.03870603],
#        ...,
#        [ 0.04989359,  0.01780826,  0.01292924, ...,  0.000545  ,
#         -0.00322097,  0.02553473],
#        [ 0.0303044 ,  0.03520963,  0.02912556, ...,  0.0076525 ,
#          0.02651281, -0.00132098],
#        [ 0.0078274 ,  0.02576613,  0.04262618, ...,  0.04018773,
#         -0.00259607, -0.05272429]])

# %%
Q,S = linalg.polar(face)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5e638f63fd91> in <module>()
# ----> 1 Q,S = linalg.polar(face)
#
# NameError: name 'face' is not defined

# %%
plt.imshow(faceholder,cmap=plt.cm.gray)

# %%
D,V = linalg.eig(Q)

# %%
D.shape
# Out:
# (85,)

# %%
V.shape
# Out:
# (85, 85)

# %%
U,S,V = linalg.svd(A)

# %%
plt.imshow(U+V,cmap=plt.cm.gray)

# %%
obama_face = ndimage.imread('data/obama.png',mode='L')
Q,S = linalg.polar(obama_face)
mean_obama_face = obama_face - (obama_face/np.prod(obama_face.shape))
U,Sigma,V = linalg.svd(mean_obama_face)

# %%
plt.imshow(Q,cmap=plt.cm.gray)

# %%
plt.imshow(U*np.diag(Sigma*Sigma)*U.T,cmap=plt.cm.gray)

# %%
svdS = np.matmul(np.matmul(U,np.matmul(np.diag(Sigma),np.diag(Sigma).T)),U.T)/U.shape[1]

# %%
plt.imshow(svdS,cmap=plt.cm.gray)

# %%
plt.imshow(S,cmap=plt.cm.gray)

# %%
plt.imshow(np.matmul(Q,S),cmap=plt.cm.gray)

# %%
np.sum([[1,2],[3,4]])
# Out:
# 10
