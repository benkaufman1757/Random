# %%
topics = ['abortion',
          'economy',
          'education',
          'energy',
          'environment',
          'gayRights',
          'guns',
          'healthcare',
          'immigration',
          'socialSecurity',
          'taxReform',
          'war']

# %%
import requests
response = requests.get('http://edition.cnn.com/2008/TECH/space/12/04/nasa.mars.delay/index.html?eref=edition_space&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+rss%2Fedition_space+%28RSS%3A+CNNi+-+Science+%26+Space%29')

# %%
response.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html lang="en"><head><script type="text/javascript" src="http://i.cdn.turner.com/cnn/.element/js/2.0/ad_head0.js"></script>\n<script type="text/javascript" src="http://i.cdn.turner.com/cnn/cnn_adspaces/cnn_adspaces.js"></script>\n<title>Mars Science Lab launch delayed two years - CNN.com</title><meta name="TITLE" content="Mars Science Lab launch delayed two years - CNN.com"><meta name="description" content="NASA\'s launch of the Mars Science Laboratory -- hampered by technical difficulties and cost overruns -- has been delayed until the fall of 2011, NASA officials said at a news conference Thursday in Washington."><meta name="AUTHOR" content="By\xa0 \xa0Alan Silverleib CNN"><meta name="SECTION" content="TECH"><meta name="SUBSECTION" content="space"><meta name="KEYWORDS" content="Unmanned Space Exploration, Science and Technology, The New York Times Company, California, Ed Weiler, 
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text)

# %%
soup.find("body").findAll("p")
# Out:
# [<p> <b>WASHINGTON (CNN)</b> -- NASA's launch of the Mars Science Laboratory -- hampered by technical difficulties and cost overruns -- has been delayed until the fall of 2011, NASA officials said at a news conference Thursday in Washington.</p>,
#  <p><!--===========CAPTION==========-->A photo illustration of a laser-equipped vehicle that is set to be part of the Mars Science Laboratory.<!--===========/CAPTION=========--></p>,
#  <p> The mission had been scheduled for launch in the fall of 2009.</p>,
#  <p> The Mars Science Lab is a large, nuclear-powered rover designed to traverse long distances with a suite of onboard scientific instruments aboard. </p>,
#  <p> It is, according to NASA's Web site, part of a "long-term effort of robotic exploration" established to "study the early environmental history of Mars" and assess whether Mars has ever been -- or still is -- able to sustain life.</p>,
# ...

# %%
from sklearn.datasets import fetch_20newsgroups

d = fetch_20newsgroups()

# %%
d.keys()
# Out:
# dict_keys(['target', 'DESCR', 'filenames', 'target_names', 'data'])

# %%
type(d.data)
# Out:
# list

# %%
len(d.data)
# Out:
# 11314

# %%
d.data[0]
# Out:
# "From: lerxst@wam.umd.edu (where's my thing)\nSubject: WHAT car is this!?\nNntp-Posting-Host: rac3.wam.umd.edu\nOrganization: University of Maryland, College Park\nLines: 15\n\n I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.\n\nThanks,\n- IL\n   ---- brought to you by your neighborhood Lerxst ----\n\n\n\n\n"

# %%
from s
vectorizer = TfidfVectorizer(max_df=0.5, max_features=opts.n_features,
                                 min_df=2, stop_words='english',
                                 use_idf=opts.use_idf)
